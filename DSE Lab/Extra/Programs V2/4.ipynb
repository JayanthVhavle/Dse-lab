# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
df=pd.read_csv("C:/Users/Dell/Documents/P4_winequality.csv")

# %%
df['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
# 5       5
# 6       5
# 7       7
# 8       7
# 9       5
# 10      5
# 11      5
# 12      5
# 13      5
# 14      5
# 15      5
# 16      7
# 17      5
# 18      4
# 19      6
# 20      6
# 21      5
# 22      5
# 23      5
# 24      6
# 25      5
# 26      5
# 27      5
# 28      5
# 29      6
#        ..
# 1569    6
# 1570    6
# 1571    6
# 1572    5
# 1573    6
# 1574    6
# 1575    6
# 1576    6
# 1577    6
# 1578    6
# 1579    5
# 1580    6
# 1581    5
# 1582    5
# 1583    5
# 1584    7
# 1585    6
# 1586    6
# 1587    6
# 1588    6
# 1589    5
# 1590    6
# 1591    6
# 1592    6
# 1593    6
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
df.describe().head(5)
X=df.drop(['quality'],axis=1)

# %%
y=df['quality'].values

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
y_pred=knn.predict(X_test)

# %%
df=pd.DataFrame({'Actual':y_test.flatten(),'Predicted':y_pred.flatten()})
df1=df.head(5)
df1.plot(kind='bar')

plt.grid(which='major',linewidth='0.5')
plt.grid(which='minor',linewidth='0.5')
plt.show()

# %%
metrics.mean_absolute_error(y_test,y_pred)
# Out:
# 0.60624999999999996

# %%
df=pd.DataFrame({'Actual':y_test.flatten(),'Predicted':y_pred.flatten()})
df1=df.head(5)
df1.plot(kind='bar',figsize=(16,10))

plt.grid(which='major',linewidth='0.5')
plt.grid(which='minor',linewidth='0.5')
plt.show()

# %%
orig=np.where(y_test>5,'Good','BAd')
pred=np.where(y_pred>5,'Good','BAd')

# %%
s=pd.DataFrame({'actual':orig,'Pred':pred})

# %%
s
# Out:
#      Pred actual
# 0     BAd   Good
# 1     BAd    BAd
# 2    Good   Good
# 3     BAd   Good
# 4     BAd    BAd
# 5    Good   Good
# 6     BAd    BAd
# 7    Good   Good
# 8    Good    BAd
# 9     BAd    BAd
# 10    BAd    BAd
# 11    BAd    BAd
# 12    BAd   Good
# 13   Good    BAd
# 14    BAd   Good
# 15   Good   Good
# 16   Good   Good
# 17   Good    BAd
# 18    BAd    BAd
# 19    BAd    BAd
# 20   Good   Good
# 21   Good   Good
# 22   Good   Good
# 23    BAd    BAd
# 24    BAd   Good
# 25    BAd    BAd
# 26   Good    BAd
# 27   Good   Good
# 28    BAd    BAd
# 29   Good   Good
# ..    ...    ...
# 290   BAd    BAd
# 291   BAd   Good
# 292  Good   Good
# 293   BAd   Good
# 294   BAd    BAd
# 295  Good   Good
# 296   BAd   Good
# 297   BAd    BAd
# 298   BAd   Good
# 299  Good    BAd
# 300  Good   Good
# 301   BAd    BAd
# 302   BAd   Good
# 303   BAd   Good
# 304   BAd   Good
# 305  Good   Good
# 306   BAd    BAd
# 307   BAd    BAd
# 308  Good   Good
# 309   BAd    BAd
# 310   BAd    BAd
# 311  Good   Good
# 312   BAd    BAd
# 313  Good    BAd
# 314  Good    BAd
# 315  Good   Good
# 316   BAd    BAd
# 317  Good    BAd
# 318   BAd    BAd
# 319  Good   Good
#
# [320 rows x 2 columns]

# %%
knn.score(X_test,y_test)
# Out:
# 0.51249999999999996
